# %% [markdown]
# # Data processing for director-firm samples
# In this notebook I am creating a file that includes the control variables for each company and each year and I am matching the ISINs to those firms. In addition, I am identifying all relevant directors that sit on the board between 2011 and 2015 of all relevant companies (using the Refinitiv Eikon director data). Moreover, I run some sanity checks to see whether the director data is complete. Comparing the number of directors taken from the Refinitiv data to the board size data (also from Refinitiv), I can see that there are many inconsistencies (for details, scroll further down). However, it is not possible to manually confirm who is sitting on these boards, so I will accept the Refinitiv Eikon director data as is and assume that this represents the correct and true board composition per company and year. I will write the preprocessed director data and the committee data (also from Refinitiv Eikon) to csv files so that they can be used in the `biography_matching` notebook and the `csr_committees` notbook.

# %%
# connecting to Google Drive to access files
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
from glob import glob
import os
import xlrd
import tqdm.notebook as tqdm
from functools import reduce

# %%
# change settings to display full width of column content
pd.set_option('display.max_colwidth', None)
# set number of max rows
pd.set_option('display.max_rows', 13000)

# %%
# Disable pandas warning about chained assignments
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ## Read in data

# %%
# read in the founding year csv file which contains company tickers, names, and ISINs
founding_year_df = pd.read_csv('/content/drive/My Drive/director-csr/control_variables/founding_year.csv')
founding_year_df['Instrument'] = founding_year_df['Instrument'].apply(lambda x: x.split('.')[0])
founding_year_df.rename(columns={'ISIN Code': 'ISIN',
                                 'Instrument': 'ticker',
                                 '2016': 'part_of_2016',
                                 '2015': 'part_of_2015',
                                 '2014': 'part_of_2014',
                                 '2013': 'part_of_2013',
                                 '2012': 'part_of_2012',
                                 '2011': 'part_of_2011',
                                 '2010': 'part_of_2010'}, inplace=True)
founding_year_df.head()
# Out:
#   ticker  Organization Founded Year  ... part_of_2011 part_of_2010
# 0    MMM                       1929  ...       2011.0       2010.0
# 1    ABT                       1900  ...       2011.0       2010.0
# 2   ABBV                       2012  ...          NaN          NaN
# 3    ACN                       2009  ...       2011.0          NaN
# 4   ATVI                       2000  ...          NaN          NaN
#
# [5 rows x 12 columns]

# %%
def excel_read_in(file, list_of_dfs):
    '''
    Function to read in excel file and get the ticker from the file name
    and the company name from the first line of the excel file, then
    write the content to a pd.DataFrame
    '''
    # get the ticker from the file name
    ticker = os.path.basename(file).split('_')[0]
    # open the excel file and get the company name from the first row
    excel_sheet = xlrd.open_workbook(file)
    prim_sheet = excel_sheet.sheet_by_index(0)
    first_line = str(prim_sheet.row_slice(0)[0])[6:]
    company_name = first_line.split('|')[0].strip()
    # skipping the first 4 rows above the header
    df_file = pd.read_excel(file, skiprows=4)
    # add the company name and the ticker to the dataframe
    df_file['comp_name'] = company_name
    df_file['ticker'] = ticker
    list_of_dfs.append(df_file)

    return list_of_dfs

# %%
# reading in the Excel files containing the directors per company
all_files = glob('/content/drive/My Drive/director-csr/directors_firms/*.xlsx')

all_directors_dfs = []
all_committees_dfs = []

# iterate through all file names
for file in tqdm.tqdm(all_files):

    # if the file name contains _dir
    if '_dir' in file:
        excel_read_in(file, all_directors_dfs)
    
    # if the file name contains _com
    elif '_com' in file:
        excel_read_in(file, all_committees_dfs)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=977.0), HTML(value='')))

# %% [markdown]
# ## Preprocessing data

# %%
# list of tickers contained in the all_directors_dfs
all_tickers = []
for df in all_directors_dfs:
    all_tickers.append(df['ticker'].iloc[0].lower())

# list of all tickers contained in the founding_year_df
all_tickers_founding = list(founding_year_df['ticker'].str.lower())

# items contained in all_tickers list but not in the founding_year_df
tickers_no_founding = [x for x in all_tickers if x not in all_tickers_founding]
tickers_no_founding
# Out:
# ['0ieo', 'bpyu', 'chkaq', 'cta', 'dofsq', 'ftc', 'ftrcq']

# %% [markdown]
# I need to manually check what company and ISIN these tickers could belong to.

# %%
# check '0ieo' --> according to review, the old ticker was etfc
print('etfc' in all_tickers_founding)

# check 'bpyu' --> according to review, the old ticker was ggp
print('ggp' in all_tickers_founding)

# check 'chkaq' --> according to review, the old ticker was chk
print('chk' in all_tickers_founding)

# check 'cta' --> according to review, the old ticker was dd
print('dd' in all_tickers_founding)

# check 'dofsq' --> according to review, the old ticker was do
print('do' in all_tickers_founding)

# check 'ftc' --> there is no company that matches the founding year data

# check 'ftrcq' --> according to review, the old ticker was ftr
print('ftr' in all_tickers_founding)
# Out:
# True
# True
# True
# True
# True
# True

# %%
# get the list index for 'ftc'
for i, df in enumerate(all_directors_dfs):
    if df['ticker'].iloc[0].lower() == 'ftc':
        print(i)
        del all_directors_dfs[i]
# Out:
# 201

# %%
# there are two additional tickers which need to be removed from the drop_index for the founding_year_df
addtl_comps = ['aaba', 'adt']

# %%
# replace all new tickers with old ones to match the founding_year_df tickers
# so that later on I can match ISINs to them
all_tickers_dir = []
all_tickers_com = []
# I have added the addtl_comps tickers to ensure that I get their list index and
# can remove them from the drop_index list
new_tickers = {'0ieo': 'etfc', 'bpyu': 'ggp', 'chkaq': 'chk', 'cta': 'dd',
               'dofsq': 'do', 'ftrcq': 'ftr', 'aaba': 'aaba', 'adt': 'adt'}
full_tickers_founding_year = []

for ticker in new_tickers.keys():
    # replace tickers for all director dfs
    for i, df in enumerate(all_directors_dfs):
        if df['ticker'].iloc[0].lower() == ticker:
            new_ticker = new_tickers[ticker]
            df['ticker'] = new_ticker
            all_tickers_dir.append(df['ticker'].iloc[0].lower())
            # get the RIC from the founding_year_df so that these can later be removed
            # from the drop_index list which contains tickers to be dropped
            full_tickers_founding_year.append(founding_year_df[founding_year_df['ticker'].str.lower() == new_ticker].index)

    # replace tickers for all committees dfs
    for df in all_committees_dfs:
        if df['ticker'].iloc[0].lower() == ticker:
            df['ticker'] = new_tickers[ticker]
            all_tickers_com.append(df['ticker'].iloc[0].lower())

# check whether there are any unknown tickers left
tickers_no_founding_dir = [x for x in all_tickers_dir if x not in all_tickers_founding]
tickers_no_founding_com = [x for x in all_tickers_com if x not in all_tickers_founding]
print(tickers_no_founding_dir)
print(tickers_no_founding_com)
# Out:
# []
# []

# %%
# drop all companies that have been delisted because I won't have director data for them
drop_index = list(founding_year_df[founding_year_df['RIC'].str.contains('\^')].index)
# remove items from that drop list which actually have data based on 
for element in full_tickers_founding_year:
    drop_index.remove(element)

# drop all remaining companies
founding_year_df.drop(index=drop_index, inplace=True)

# convert the content all relevant columns to lower case
for column in founding_year_df.columns:
    try:
        founding_year_df[column] = founding_year_df[column].str.lower()
    except:
        print('Column does not contain string values', column)

print(founding_year_df.shape)
founding_year_df.head()
# Out:
# Column does not contain string values Organization Founded Year
# Column does not contain string values part_of_2016
# Column does not contain string values part_of_2015
# Column does not contain string values part_of_2014
# Column does not contain string values part_of_2013
# Column does not contain string values part_of_2012
# Column does not contain string values part_of_2011
# Column does not contain string values part_of_2010
# (496, 12)
#   ticker  Organization Founded Year  ... part_of_2011 part_of_2010
# 0    mmm                       1929  ...       2011.0       2010.0
# 1    abt                       1900  ...       2011.0       2010.0
# 2   abbv                       2012  ...          NaN          NaN
# 3    acn                       2009  ...       2011.0          NaN
# 4   atvi                       2000  ...          NaN          NaN
#
# [5 rows x 12 columns]

# %%
# define the list of observed years
year_list = ['2011', '2012', '2013', '2014', '2015']

# %%
# read in the file that contains board size
control_vars_df = pd.read_excel('/content/drive/My Drive/director-csr/control_variables/control_vars.xlsx')
# create separate df with only ISINs
control_vars_isin = control_vars_df[['ISIN Code']]
control_vars_isin['ISIN Code'] = control_vars_isin['ISIN Code'].str.lower()
control_vars_df.drop(columns=['ISIN Code'], inplace=True)
# drop rows that have all values missing
control_vars_df.dropna(how='all', inplace=True)
# convert the years from float to int
control_vars_df['Name'].astype(int)
# Out:
# 0    2010
# 1    2011
# 2    2012
# 3    2013
# 4    2014
# 5    2015
# 6    2016
# Name: Name, dtype: int64

# %%
# check how many control variables are included per company
upper = '3m'.upper()
num_col_company_df = control_vars_df.filter(regex=upper)
print(num_col_company_df.shape)
# the first column containing the years needs to be subtracted
print((control_vars_df.shape[1]-1)/18)
# Out:
# (7, 18)
# 630.0

# %%
# how many ISINs are included
print(control_vars_isin.shape)
# Out:
# (630, 1)

# %%
# create a list of all ISINs that will be inserted as a row in the control_vars_df
all_isins_list = [item for isin in control_vars_isin['ISIN Code'] for item in [isin]*18]

# turn the Name column which contains the years into the index
control_vars_df['Name'] = control_vars_df['Name'].astype(int)
control_vars_df.set_index('Name', inplace=True)
#control_vars_df.index.name = 'year'

# add all ISINs to the table
control_vars_df.loc[0] = all_isins_list
control_vars_df
# Out:
#      3M - Value - Board Structure/Independent Board Members  ... TELLABS - PRICE VOLATILITY
# Name                                                         ...
# 2010                                                     90  ...                      35.47
# 2011                                                     90  ...                      33.32
# 2012                                                  81.82  ...                      31.87
# 2013                                                  91.67  ...                        NaN
# 2014                                                  92.31  ...                        NaN
# 2015                                                  90.91  ...                        NaN
# 2016                                                  92.31  ...                        NaN
# 0                                              us88579y1010  ...               us8796641004
#
# [8 rows x 11340 columns]

# %%
# check whether there are any duplicate tickers in founding_year_df
founding_year_df[founding_year_df['ticker'].duplicated()]
# Out:
# Empty DataFrame
# Columns: [ticker, Organization Founded Year, RIC, Company Name, ISIN, part_of_2016, part_of_2015, part_of_2014, part_of_2013, part_of_2012, part_of_2011, part_of_2010]
# Index: []

# %%
# get a list of all the available variables
all_vars_headers = list(control_vars_df.columns[:18])
all_vars = [x.split('-')[-1].strip() for x in all_vars_headers]
print(len(all_vars))
all_vars
# Out:
# 18
# ['Board Structure/Independent Board Members',
#  'Board Structure/Strictly Independent Board Members',
#  'Board Size',
#  'Chairman Separation',
#  'Board Structure/Specific Skills',
#  'RETURN ON ASSETS',
#  'TOTAL DEBT % COMMON EQUITY',
#  'TOTAL DEBT % TOTAL CAPITAL/STD',
#  'TOTAL DEBT % TOTAL ASSETS',
#  'NET SALES OR REVENUES',
#  '1YR ANN GR',
#  '3YR ANN GROWTH',
#  'Compensation Policy Elements/Policy ESG Related Compensation',
#  'Board Structure/Board Diversity',
#  'CASH FLOW/SALES',
#  'CASH & EQUIVALENTS % TOTAL CUR',
#  'Board Structure/Experienced Board',
#  'PRICE VOLATILITY']

# %%
def yearly_controls(str_control, year):
    '''
    Function to create separate dataframes per year for all companies
    and control variables
    '''

    # get all columns that contain particular control variable
    one_control_df = control_vars_df.filter(regex=str_control)
    # print the number of columns indicating the number of companies with that data
    
    # transpose the dataframe
    one_control_T = one_control_df.T
    one_control_T.reset_index(inplace=True)
    one_year_df = one_control_T[['index', year, 0]].copy()

    # change the column names
    one_year_df.rename(columns={'index': 'company', year: str_control, 0: 'ISIN'}, inplace=True)

    # drop the column of company name because the same isin may have different company names
    one_year_df.drop(columns='company', inplace=True)

    return one_year_df

# %%
# create dataframes for each year and control variable
all_years_dict = {}
# create a variable that captures the overall size of all combined dataframes
# this will serve as a sanity check to confirm that the merging has correctly worked
all_dfs_length = 0

# iterate through all years that will be observed
for year in year_list:
    # define an empty list to save all generated dfs in
    list_dfs_control_vars = []
    # iterate through all observed control variables
    for variable in all_vars:
        # generate the dfs containing the variable for a specific year
        df = yearly_controls(variable, int(year))
        # add this df to a list
        list_dfs_control_vars.append(df)

    # merge the dataframes for the same year
    all_vars_for_year = reduce(lambda left, right: pd.merge(left, right, on=['ISIN'], # merge just on isin
                                            how='outer'), list_dfs_control_vars)
    
    # add the founding_year_df to the all_years_dict entries
    all_vars_founding_year = pd.merge(founding_year_df, all_vars_for_year, on=['ISIN'], how='outer')

    # add a column that contains the year these samples related to
    all_vars_founding_year['year'] = year

    # add the merged dataframes to a list
    all_years_dict[year] = all_vars_founding_year

    # add the shape of the dataframe to the overall length variable
    all_dfs_length += all_vars_founding_year.shape[0]

# %%
# now merge all the dataframes containing control variables for different years
# into one overall dataframe
for key, val in all_years_dict.items():
    if key == '2011':
        all_control_vars_df = val.copy()
    else:
        all_control_vars_df = all_control_vars_df.append(val)

# %%
# check the shapes of the dataframes
print('Overall dataframe:', all_control_vars_df.shape[0])
print('Individual combined dataframes:', all_dfs_length)
# Out:
# Overall dataframe: 3145
# Individual combined dataframes: 3145

# %%
# write control variable data to csv files
all_control_vars_df.to_csv('/content/drive/My Drive/director-csr/control_variables/all_control_vars.csv')

# %% [markdown]
# Independent directors will be considered for their entire tenure at the organizations, not just for in position, because by definition, independent directors cannot be former employees, therefore, they could not have held executive positions prior to becoming independent directors. The reason I will consider this is because in the case of fortune brands home & security inc there is a lead independent director which held a position prior to that. However, the prior position is not named. Yet, checking perid.org shows that he was previously an independent (not lead) director at this company.

# %%
def preprocess(df, committee=False):
    '''
    Function to preprocess dataframes
    Args: df = pd.DataFrame
          committee = boolean
    Returns: df = pd.DataFrame
    '''
    # replace all -- with NaN
    df = df.replace('--', np.nan)

    # convert all entries to lower case
    for column in df.columns:
        # applying lower() to the age column converts all ages to NaN, therefore,
        # this column will be skipped when converting content to lower case
        if column == 'Alter':
            pass
        else:
            df[column] = df[column].str.lower()     

    try:   
        # define the new columns depending on whether this is director or committee data
        if committee:
            new_cols_current = ['name', 'committee', 'age', 'current_position', 'dir_exec', 'in_position']
            new_cols_former = ['name', 'committee', 'age', 'last_position', 'director_start', 'director_end', 'executive_start', 'executive_end']
            current_df, former_df = np.split(df, df.index[df[df.columns[:-2]].isnull().all(1)])

            # drop Gesamtvergütung column and Unnamed column
            if former_df.iloc[2]['Name'] != 'name':
                current_df = current_df.drop(current_df.columns[[-3]], axis=1)
            else: 
                current_df = current_df.drop(current_df.columns[[-4, -3]], axis=1)

        else:
            new_cols_current = ['name', 'age', 'current_position', 'dir_exec', 'in_position']
            new_cols_former = ['name', 'age', 'last_position', 'director_start', 'director_end', 'executive_start', 'executive_end']
            # split the dataframe on the line that contains NaN in the Name column
            current_df, former_df = np.split(df, df[df.isnull().Name].index)
            
            # some tickers have Gesamtvergütung with pound sign, not dollar sign
            if 'Gesamtvergütung ($)' in current_df.columns:
                current_df = current_df.drop(columns=['Gesamtvergütung ($)', 'Unnamed: 6'])
            else:
                current_df = current_df.drop(current_df.columns[[-4, -3]], axis=1)

        # define new column names
        current_df = current_df.rename(columns=dict(zip(current_df.columns[:-2], new_cols_current)))

        # drop empty rows and rename columns
        if former_df.iloc[2]['Name'] == 'name':
            former_df_index = former_df.reset_index(drop=True).loc[2:, :]
            # define new column names
            former_df_index = former_df_index.rename(columns=dict(zip(former_df_index.columns[:-2], new_cols_former)))
            former_df = former_df_index.iloc[1:]
        else: 
            try:
                print ('This company has a problematic layout of the former director table:',
                former_df['ticker'][0])       
            except:
                print('The former_df dataframe is empty')
                former_df = pd.DataFrame(data=None)

        # drop all directors that did not hold director positions (because Reuters incorrectly
        # translated the fields, I need to look at the executive start and end fields)
        if committee:
            pass
        else:
            former_df = former_df.dropna(subset=['executive_start', 'executive_end'], how='all')

        # if the former_df is empty
        if former_df.empty:
            pass
        else:
            # convert dates to just years
            for col_name in ['director_start', 'director_end', 'executive_start', 'executive_end']:
                former_df[col_name] = former_df[col_name].apply(lambda x: 0 if isinstance(x, float)
                                                                        else x[-4:])
            # flag the directors without start date but only an end date after 2009
            former_df['missing_start_date'] = former_df.apply(lambda x: 1 if int(x['executive_start']) == 0 and int(x['executive_end']) > 2009 
                                                                        else 0, axis=1)
            
            # add columns for each year
            for year in year_list:
                # I will only consider the executive positions for the year fields
                former_df[year] = former_df.apply(lambda x: 1 if int(x['executive_start']) <= int(year) and int(x['executive_start']) != 0 
                                                                        and int(x['executive_end']) >= int(year) else 0, axis=1)

        # isolate number of years from dir_exec and in_position columns
        current_df['dir_exec'] = current_df['dir_exec'].apply(lambda x: 0 if isinstance(x, float)
                                                                        else (2021 - int(x.split(' ')[1]) if len(x.split(' ')) == 3
                                                                              else 2021 - int(x.split(' ')[0])))
        current_df['in_position'] = current_df['in_position'].apply(lambda x: 0 if isinstance(x, float)
                                                                              else (2021 - int(x.split(' ')[1]) if len(x.split(' ')) == 3
                                                                                    else 2021 - int(x.split(' ')[0])))

        # drop people in director dataframes
        if committee:
            current_df_new = current_df.copy()
        else:
            # drop all people that held positions other than directors
            df_combined = current_df[current_df['current_position'].str.contains('director|chairman|independent|non-executive', regex=True)]
            # drop any current directors whose dir_exec column holds a value greater than 2016
            current_df_new = df_combined[df_combined['dir_exec'] < 2017]

        # don't do anything if there are no directors currently on the board who were appointed before 2017
        if current_df_new.empty:
            pass
        else:
            # add columns for each year
            for year in year_list:
                # I will only consider the current in_position field for the year columns
                current_df_new[year] = current_df_new.apply(lambda x: 1 if int(x['in_position']) <= int(year) and int(x['in_position']) != 0
                                                                        else 0, axis=1)
                # if there is an independent director with a prior role, I will also consider this prior role because they likely also were director
                current_df_new[year] = current_df_new.apply(lambda x: 1 if 'independent' in x['current_position'] and int(x['dir_exec']) <= int(year) and int(x['dir_exec']) != 0
                                                                    else x[year], axis=1)

        # compress committee membership into list per director
        if committee:
            # do the below iterations for both former and current dfs
            both_dfs = [current_df_new, former_df]
            for df in both_dfs:
                # don't do anything if the former_df dataframe is empty
                if df.empty:
                    pass
                else:
                    committees_start_end = list(df.index[df['committee'].isnull()])
                    # add the length of the committee column to the index list to ensure that
                    # the last director also gets his/her committees assigned
                    committees_start_end.append(df['committee'].index[-1]+1)
                    for i in range(len(committees_start_end)-1):
                        committee_memb = list(df['committee'].loc[committees_start_end[i]+1 : committees_start_end[i+1]-1])
                        df['committee'].loc[committees_start_end[i]] = committee_memb

                    # drop all rows that have NaNs in the name column or 'komitee-mitgliedschaft'
                    df.drop(df[(df['name'].isnull()) | (df['name'] == 'komitee-mitgliedschaft')].index, inplace=True)

        else:
            pass

        return current_df_new, former_df 

    except:
        print('There seems to be an issue with this dataframe:', df['ticker'][0])

        return df['ticker'][0], df['ticker'][0]

# %%
def combine_isin(df_list, committee=False):
    '''
    Function to split all dfs, structure them and then add isin to them
    Args: df_list = df,
          committee = boolean
    Returns: all_director_dfs = df
    '''
    # iterate through all dfs and split and structure them
    all_current_dfs = []
    all_former_dfs = []
    all_director_dfs = []
    removal_index = None

    for i, df in enumerate(df_list):
        current_df, former_df = preprocess(df, committee=committee)
        all_current_dfs.append(current_df)
        all_former_dfs.append(former_df)

        try:
            df_combined = pd.concat([former_df, current_df])
        except:
            print('This list item is not a dataframe but only the ticker')

        # add a column with the ISIN to all combined dataframes
        issues_list = []
        try:
            ticker = list(df_combined['ticker'])[0]
            isin = founding_year_df[founding_year_df['ticker'] == ticker]['ISIN']
        except:
            print('This dataframe seems to be empty', df_combined, i)
            removal_index = i

        try:
            df_combined['isin'] = isin.values[0]
        except:
            issues_list.append(i)
            print('There are issues with this ticker:', ticker, i)

        all_director_dfs.append(df_combined)

    return all_director_dfs, removal_index, issues_list

# %%
# apply structure all director and committee dfs and apply isins
all_combined_dfs, removal_index, issues_list = combine_isin(all_directors_dfs, committee=False)
all_committees_dfs, removal_index_comm, issues_list_comm = combine_isin(all_committees_dfs, committee=True)
# Out:
# This dataframe seems to be empty Empty DataFrame
# Columns: [name, age, last_position, director_start, director_end, executive_start, executive_end, comp_name, ticker, current_position, dir_exec, in_position]
# Index: [] 280
# There seems to be an issue with this dataframe: etfc
# This list item is not a dataframe but only the ticker
# The former_df dataframe is empty
# The former_df dataframe is empty
# The former_df dataframe is empty
# The former_df dataframe is empty
# The former_df dataframe is empty

# %% [markdown]
# I will disregard the ETFC company for now because it was delisted.

# %%
# drop the empty dataframe
del all_combined_dfs[removal_index]

# %% [markdown]
# Based on the fact that the biography data is from 2015, I will look at data from 2011 until 2016 in my analysis. The control and indepedent variables need to range from 2011 until 2015, while the dependent variable needs to range from 2012 until 2016.

# %% [markdown]
# I need to systematically compare board size with the number of directors filtered.

# %%
def check_dir_size(df_list):
    '''
    Function to check whether the number of filtered directors is
    the same as the board size
    '''

    too_high = []
    too_low = []

    for company_index in range(len(df_list)):
        # if the current company is part of the issues_list generated earlier, skip it
        if company_index in issues_list:
            pass

        else:
            # get the company isin and name
            company_isin = df_list[company_index]['isin'].iloc[0]
            company_name = df_list[company_index]['comp_name'].iloc[0]

            # check for all years covered
            for year in year_list:

                # get the board size from the control variables df
                comp_filtered = list(all_years_dict[year][all_years_dict[year]['ISIN'] == company_isin]['Board Size'])
                comp_board_size = [x for x in comp_filtered if not pd.isna(x)]

                # get the number of directors
                num_dir_year = df_list[company_index][df_list[company_index][year] == 1].shape[0]
                
                # try to check whether the number of directors in a given year is the same
                # as the board size given in the control variables df
                try:
                    
                    if len(comp_board_size) > 0:
                        
                        if num_dir_year == comp_board_size[0]:
                            pass
                        else:                            
                            # add incorrect matches if they are more than 1 greater or smaller than board size
                            if num_dir_year > comp_board_size[0]:
                                # check whether there is a director that has the same start and end year
                                same_start_end = list(df_list[company_index][df_list[company_index][['executive_start','executive_end']].nunique(axis=1) == 1]['executive_start'])

                                if len(same_start_end) > 0 and year in same_start_end:
                                    print('Less than one year term:', year, company_name)

                                else:
                                    too_high.append(company_index)
                                    print('Too high:', company_name, year,
                                            'directors:', num_dir_year,
                                            'board size:', comp_board_size[0], 
                                            'company index:', company_index)
                                    
                            elif num_dir_year < comp_board_size[0]:
                                # check whether there are any directors with a missing start date
                                missing_start_date = df_list[company_index][df_list[company_index]['missing_start_date'] == 1][['name', 'last_position', 'executive_end']]
                                
                                if any(int(x) > 2010 for x in list(missing_start_date['executive_end'])):
                                #for index, row in missing_start_date.iterrows():
                                 #   if int(row['executive_end']) > 2010:
                                    print('Missing start date', year, company_name)

                                else:
                                    too_low.append(company_index)
                                    print('Too low:', company_name, year,
                                            'directors:', num_dir_year,
                                            'board size:', comp_board_size[0], 
                                            'company index:', company_index)

                    else:
                        pass

                except:
                    print('There seems to be an issue with the board size column in the control variables df:',
                        company_name)
                    
    return too_high, too_low

# %%
# check the board size
too_high, too_low = check_dir_size(all_combined_dfs)
# Out:
# Missing start date 2011 itt inc
# Missing start date 2012 itt inc
# Missing start date 2013 itt inc
# Missing start date 2014 itt inc
# Missing start date 2015 itt inc
# Too low: meredith corp 2011 directors: 9 board size: 10.0 company index: 1
# Too high: meredith corp 2014 directors: 9 board size: 8.0 company index: 1
# Too high: willis towers watson plc 2012 directors: 12 board size: 11.0 company index: 2
# Too high: willis towers watson plc 2013 directors: 15 board size: 12.0 company index: 2
# Too high: willis towers watson plc 2015 directors: 12 board size: 6.0 company index: 2
# Too low: udr inc 2011 directors: 8 board size: 9.0 company index: 3
# Too low: udr inc 2013 directors: 7 board size: 8.0 company index: 3
# Too low: ulta beauty inc 2011 directors: 4 board size: 5.0 company index: 4
# Too low: ulta beauty inc 2012 directors: 6 board size: 7.0 company index: 4
# Too low: ulta beauty inc 2014 directors: 9 board size: 10.0 company index: 4
# Too low: ulta beauty inc 2015 directors: 10 board size: 11.0 company index: 4
# Too low: under armour inc 2011 directors: 7 board size: 8.0 company index: 5
# Too low: under armour inc 2012 directors: 9 board size: 10.0 company index: 5
# Too low: under armour inc 2014 directors: 9 board size: 11.0 company index: 5
# Too low: transdigm group inc 2015 directors: 9 board size: 10.0 company index: 6
# Too high: mettler-toledo international inc 2015 directors: 10 board size: 9.0 company index: 7
# Too high: mid-america apartment communities inc 2015 directors: 12 board size: 11.0 company index: 8
# Too low: lkq corp 2012 directors: 8 board size: 9.0 company index: 9
# Too low: lkq corp 2014 directors: 9 board size: 10.0 company index: 9
# Too low: lkq corp 2015 directors: 9 board size: 11.0 company index: 9
# Too high: hologic inc 2011 directors: 9 board size: 8.0 company index: 10
# Too high: hologic inc 2013 directors: 12 board size: 8.0 company index: 10
# Too low: hologic inc 2014 directors: 10 board size: 11.0 company index: 10
# Too high: hologic inc 2015 directors: 11 board size: 9.0 company index: 10
# Too high: foot locker inc 2011 directors: 11 board size: 9.0 company index: 11
# Too high: foot locker inc 2013 directors: 12 board size: 11.0 company index: 11
# Too high: foot locker inc 2014 directors: 10 board size: 9.0 company index: 11
# Too low: foot locker inc 2015 directors: 10 board size: 11.0 company index: 11
# Too low: fortune brands home & security inc 2011 directors: 7 board size: 8.0 company index: 13
# Too low: fortune brands home & security inc 2012 directors: 7 board size: 8.0 company index: 13
# Too low: fortune brands home & security inc 2013 directors: 7 board size: 8.0 company index: 13
# Too low: fortune brands home & security inc 2014 directors: 7 board size: 8.0 company index: 13
# Too low: fortune brands home & security inc 2015 directors: 7 board size: 9.0 company index: 13
# Too high: global payments inc 2013 directors: 10 board size: 9.0 company index: 14
# Too high: global payments inc 2014 directors: 10 board size: 9.0 company index: 14
# Too low: extra space storage inc 2014 directors: 7 board size: 8.0 company index: 15
# Too low: extra space storage inc 2015 directors: 7 board size: 9.0 company index: 15
# Too low: federal realty investment trust 2011 directors: 6 board size: 8.0 company index: 16
# Too low: federal realty investment trust 2012 directors: 6 board size: 8.0 company index: 16
# Too low: federal realty investment trust 2013 directors: 6 board size: 8.0 company index: 16
# Too low: federal realty investment trust 2014 directors: 6 board size: 8.0 company index: 16
# Too low: federal realty investment trust 2015 directors: 6 board size: 8.0 company index: 16
# Too high: digital realty trust inc 2012 directors: 7 board size: 6.0 company index: 17
# Too high: digital realty trust inc 2015 directors: 8 board size: 7.0 company index: 17
# Too low: cooper companies inc 2011 directors: 7 board size: 8.0 company index: 18
# Too low: cooper companies inc 2012 directors: 7 board size: 8.0 company index: 18
# Too low: cooper companies inc 2013 directors: 8 board size: 9.0 company index: 18
# Too low: cooper companies inc 2014 directors: 8 board size: 9.0 company index: 18
# Too low: coty inc 2015 directors: 7 board size: 8.0 company index: 19
# Too low: centene corp 2014 directors: 8 board size: 9.0 company index: 20
# Too low: centene corp 2015 directors: 8 board size: 9.0 company index: 20
# Too low: charter communications inc 2012 directors: 5 board size: 6.0 company index: 21
# Too low: charter communications inc 2013 directors: 9 board size: 10.0 company index: 21
# Too low: charter communications inc 2014 directors: 9 board size: 10.0 company index: 21
# Too low: charter communications inc 2015 directors: 9 board size: 10.0 company index: 21
# Too low: acuity brands inc 2014 directors: 8 board size: 10.0 company index: 23
# Too low: acuity brands inc 2015 directors: 10 board size: 11.0 company index: 23
# Too low: arthur j gallagher & co 2011 directors: 8 board size: 9.0 company index: 24
# Too low: arthur j gallagher & co 2012 directors: 8 board size: 9.0 company index: 24
# Too low: arthur j gallagher & co 2014 directors: 8 board size: 9.0 company index: 24
# Too low: arthur j gallagher & co 2015 directors: 8 board size: 9.0 company index: 24
# Too high: albemarle corp 2011 directors: 12 board size: 11.0 company index: 26
# Too high: albemarle corp 2012 directors: 13 board size: 10.0 company index: 26
# Too high: albemarle corp 2013 directors: 11 board size: 10.0 company index: 26
# Too high: albemarle corp 2015 directors: 12 board size: 11.0 company index: 26
# Too high: alliant energy corp 2012 directors: 11 board size: 10.0 company index: 27
# Too high: alliant energy corp 2013 directors: 11 board size: 10.0 company index: 27
# Too high: alliant energy corp 2014 directors: 10 board size: 9.0 company index: 27
# Too high: alliant energy corp 2015 directors: 11 board size: 10.0 company index: 27
# Too high: american water works company inc 2014 directors: 9 board size: 8.0 company index: 28
# Too high: e*trade financial corp 2011 directors: 12 board size: 11.0 company index: 29
# Too high: e*trade financial corp 2012 directors: 14 board size: 12.0 company index: 29
# Too high: e*trade financial corp 2013 directors: 15 board size: 13.0 company index: 29
# Too high: e*trade financial corp 2014 directors: 14 board size: 12.0 company index: 29
# Too high: altaba inc 2011 directors: 11 board size: 9.0 company index: 31
# Less than one year term: 2012 altaba inc
# Too high: altaba inc 2013 directors: 11 board size: 7.0 company index: 31
# Too high: altaba inc 2014 directors: 10 board size: 8.0 company index: 31
# Too high: altaba inc 2015 directors: 9 board size: 8.0 company index: 31
# Too high: american airlines group inc 2011 directors: 14 board size: 11.0 company index: 32
# Too high: american airlines group inc 2013 directors: 14 board size: 12.0 company index: 32
# Too high: american airlines group inc 2014 directors: 12 board size: 11.0 company index: 32
# Too low: american airlines group inc 2015 directors: 11 board size: 13.0 company index: 32
# Too high: advance auto parts inc 2011 directors: 11 board size: 10.0 company index: 33
# Too high: advance auto parts inc 2013 directors: 10 board size: 9.0 company index: 33
# Too low: advance auto parts inc 2015 directors: 13 board size: 14.0 company index: 33
# Too high: apple inc 2014 directors: 9 board size: 8.0 company index: 34
# Too high: apple inc 2015 directors: 8 board size: 7.0 company index: 34
# Too low: amerisourcebergen corp 2012 directors: 8 board size: 9.0 company index: 36
# Too low: amerisourcebergen corp 2014 directors: 10 board size: 11.0 company index: 36
# Too high: accenture plc 2011 directors: 13 board size: 12.0 company index: 37
# Too high: accenture plc 2012 directors: 14 board size: 12.0 company index: 37
# Too high: accenture plc 2014 directors: 14 board size: 13.0 company index: 37
# Too high: accenture plc 2015 directors: 13 board size: 11.0 company index: 37
# Too low: abbott laboratories 2012 directors: 11 board size: 12.0 company index: 38
# Too low: abbott laboratories 2013 directors: 10 board size: 12.0 company index: 38
# Too low: abbott laboratories 2014 directors: 10 board size: 12.0 company index: 38
# Too low: abbott laboratories 2015 directors: 10 board size: 12.0 company index: 38
# Too low: adobe inc 2013 directors: 12 board size: 13.0 company index: 39
# Too low: adobe inc 2014 directors: 12 board size: 13.0 company index: 39
# Too low: adobe inc 2015 directors: 12 board size: 13.0 company index: 39
# Too high: analog devices inc 2012 directors: 11 board size: 10.0 company index: 40
# Too high: analog devices inc 2013 directors: 12 board size: 10.0 company index: 40
# Too high: analog devices inc 2014 directors: 12 board size: 11.0 company index: 40
# Less than one year term: 2015 analog devices inc
# Too high: archer daniels midland co 2013 directors: 12 board size: 11.0 company index: 41
# Too low: archer daniels midland co 2015 directors: 12 board size: 13.0 company index: 41
# Too high: automatic data processing inc 2011 directors: 12 board size: 11.0 company index: 42
# Too low: alliance data systems corp 2011 directors: 8 board size: 9.0 company index: 43
# Too low: alliance data systems corp 2012 directors: 8 board size: 9.0 company index: 43
# Too low: alliance data systems corp 2013 directors: 8 board size: 9.0 company index: 43
# Too low: alliance data systems corp 2014 directors: 8 board size: 9.0 company index: 43
# Too high: autodesk inc 2011 directors: 9 board size: 8.0 company index: 44
# Too high: autodesk inc 2013 directors: 10 board size: 9.0 company index: 44
# Missing start date 2012 adt inc
# Missing start date 2013 adt inc
# Missing start date 2014 adt inc
# Missing start date 2012 ameren corp
# Too high: ameren corp 2014 directors: 12 board size: 11.0 company index: 46
# Too high: american electric power company inc 2011 directors: 15 board size: 13.0 company index: 47
# Too low: american electric power company inc 2012 directors: 13 board size: 14.0 company index: 47
# Too high: american electric power company inc 2014 directors: 15 board size: 12.0 company index: 47
# Too high: aes corp 2012 directors: 12 board size: 11.0 company index: 48
# Too high: aes corp 2013 directors: 13 board size: 12.0 company index: 48
# Too high: aes corp 2015 directors: 13 board size: 10.0 company index: 48
# Too high: aflac inc 2012 directors: 16 board size: 14.0 company index: 49
# Too high: aflac inc 2013 directors: 15 board size: 14.0 company index: 49
# Too high: aflac inc 2014 directors: 14 board size: 12.0 company index: 49
# Too high: aflac inc 2015 directors: 14 board size: 13.0 company index: 49
# Too high: american international group inc 2012 directors: 13 board size: 11.0 company index: 50
# Too high: american international group inc 2013 directors: 13 board size: 12.0 company index: 50
# Too high: american international group inc 2014 directors: 14 board size: 13.0 company index: 50
# Too high: american international group inc 2015 directors: 15 board size: 14.0 company index: 50
# Missing start date 2011 apartment investment and management co
# Missing start date 2012 apartment investment and management co
# Missing start date 2013 apartment investment and management co
# Missing start date 2014 apartment investment and management co
# Missing start date 2015 apartment investment and management co
# Too high: akamai technologies inc 2015 directors: 13 board size: 11.0 company index: 52
# Too high: assurant inc 2011 directors: 14 board size: 12.0 company index: 53
# Too high: assurant inc 2013 directors: 12 board size: 11.0 company index: 53
# Too high: assurant inc 2015 directors: 11 board size: 10.0 company index: 53
# Too low: allstate corp 2011 directors: 10 board size: 11.0 company index: 54
# Too low: allstate corp 2012 directors: 11 board size: 12.0 company index: 54
# Too high: allstate corp 2013 directors: 13 board size: 12.0 company index: 54
# Too high: allstate corp 2014 directors: 13 board size: 12.0 company index: 54
# Too low: allegion plc 2013 directors: 4 board size: 5.0 company index: 55
# Too high: alexion pharmaceuticals inc 2014 directors: 14 board size: 11.0 company index: 56
# Too high: alexion pharmaceuticals inc 2015 directors: 12 board size: 11.0 company index: 56
# Too low: applied materials inc 2013 directors: 12 board size: 13.0 company index: 57
# Too high: applied materials inc 2015 directors: 14 board size: 11.0 company index: 57
# Too high: advanced micro devices inc 2011 directors: 11 board size: 10.0 company index: 58
# Too high: advanced micro devices inc 2013 directors: 13 board size: 10.0 company index: 58
# Too high: advanced micro devices inc 2015 directors: 11 board size: 9.0 company index: 58
# Too low: ametek inc 2014 directors: 8 board size: 9.0 company index: 60
# Too low: amg advanced metallurgical group nv 2011 directors: 7 board size: 9.0 company index: 61
# Too low: amg advanced metallurgical group nv 2012 directors: 7 board size: 10.0 company index: 61
# Too low: amg advanced metallurgical group nv 2013 directors: 9 board size: 10.0 company index: 61
# Too low: amg advanced metallurgical group nv 2014 directors: 10 board size: 11.0 company index: 61
# Too high: amg advanced metallurgical group nv 2015 directors: 12 board size: 9.0 company index: 61
# Too low: american tower corp 2011 directors: 8 board size: 9.0 company index: 62
# Too low: american tower corp 2012 directors: 8 board size: 9.0 company index: 62
# Too low: american tower corp 2013 directors: 8 board size: 9.0 company index: 62
# Too low: american tower corp 2014 directors: 8 board size: 10.0 company index: 62
# Too low: american tower corp 2015 directors: 9 board size: 10.0 company index: 62
# Too high: amgen inc 2011 directors: 14 board size: 13.0 company index: 63
# Too low: amgen inc 2012 directors: 13 board size: 15.0 company index: 63
# Too high: amgen inc 2013 directors: 14 board size: 13.0 company index: 63
# Too low: amgen inc 2014 directors: 12 board size: 13.0 company index: 63
# Too high: ameriprise financial inc 2014 directors: 10 board size: 9.0 company index: 64
# Too high: ameriprise financial inc 2015 directors: 9 board size: 8.0 company index: 64
# Too high: amazon.com inc 2012 directors: 10 board size: 9.0 company index: 65
# Too low: amazon.com inc 2014 directors: 9 board size: 10.0 company index: 65
# Too low: autonation inc 2011 directors: 9 board size: 10.0 company index: 66
# Too low: autonation inc 2012 directors: 9 board size: 10.0 company index: 66
# Too low: autonation inc 2014 directors: 10 board size: 11.0 company index: 66
# Too high: autonation inc 2015 directors: 11 board size: 10.0 company index: 66
# Too high: abercrombie & fitch co 2011 directors: 9 board size: 7.0 company index: 67
# Less than one year term: 2015 abercrombie & fitch co
# Too high: anthem inc 2011 directors: 14 board size: 11.0 company index: 68
# Too high: anthem inc 2012 directors: 11 board size: 10.0 company index: 68
# Too high: anthem inc 2013 directors: 13 board size: 10.0 company index: 68
# Too high: anthem inc 2014 directors: 11 board size: 10.0 company index: 68
# Too high: anthem inc 2015 directors: 10 board size: 9.0 company index: 68
# Too high: apache corp 2012 directors: 13 board size: 12.0 company index: 69
# Too high: apache corp 2013 directors: 13 board size: 10.0 company index: 69
# Too high: apache corp 2014 directors: 12 board size: 11.0 company index: 69
# Too high: apache corp 2015 directors: 13 board size: 11.0 company index: 69
# Too high: air products and chemicals inc 2012 directors: 12 board size: 11.0 company index: 70
# Too low: air products and chemicals inc 2013 directors: 12 board size: 15.0 company index: 70
# Too high: air products and chemicals inc 2014 directors: 14 board size: 11.0 company index: 70
# Too high: air products and chemicals inc 2015 directors: 12 board size: 8.0 company index: 70
# Too high: amphenol corp 2014 directors: 9 board size: 8.0 company index: 71
# Too low: adtalem global education inc 2013 directors: 11 board size: 12.0 company index: 72
# Too low: adtalem global education inc 2014 directors: 9 board size: 10.0 company index: 72
# Too low: adtalem global education inc 2015 directors: 8 board size: 9.0 company index: 72
# Too low: allegheny technologies inc 2012 directors: 10 board size: 11.0 company index: 73
# Too high: allegheny technologies inc 2014 directors: 11 board size: 10.0 company index: 73
# Too high: aptiv plc 2013 directors: 12 board size: 11.0 company index: 74
# Too high: aptiv plc 2015 directors: 15 board size: 13.0 company index: 74
# Too low: activision blizzard inc 2011 directors: 11 board size: 12.0 company index: 75
# Less than one year term: 2012 activision blizzard inc
# Too high: activision blizzard inc 2013 directors: 11 board size: 7.0 company index: 75
# Too low: activision blizzard inc 2014 directors: 7 board size: 8.0 company index: 75
# Too low: avalonbay communities inc 2011 directors: 7 board size: 9.0 company index: 76
# Too low: avalonbay communities inc 2012 directors: 8 board size: 9.0 company index: 76
# Too low: avalonbay communities inc 2014 directors: 8 board size: 10.0 company index: 76
# Missing start date 2011 broadcom inc
# Missing start date 2012 broadcom inc
# Missing start date 2013 broadcom inc
# Missing start date 2014 broadcom inc
# Missing start date 2015 broadcom inc
# Too high: avery dennison corp 2011 directors: 12 board size: 11.0 company index: 78
# Too low: avery dennison corp 2012 directors: 11 board size: 12.0 company index: 78
# Too high: avery dennison corp 2013 directors: 13 board size: 12.0 company index: 78
# Too high: avery dennison corp 2014 directors: 12 board size: 10.0 company index: 78
# Too high: avery dennison corp 2015 directors: 10 board size: 9.0 company index: 78
# Too high: american express co 2012 directors: 14 board size: 13.0 company index: 79
# Too high: american express co 2013 directors: 15 board size: 13.0 company index: 79
# Too low: autozone inc 2013 directors: 9 board size: 11.0 company index: 80
# Too high: boeing co 2011 directors: 13 board size: 12.0 company index: 81
# Too low: boeing co 2013 directors: 10 board size: 11.0 company index: 81
# Too low: boeing co 2014 directors: 10 board size: 11.0 company index: 81
# Too low: boeing co 2015 directors: 12 board size: 13.0 company index: 81
# Too low: bank of america corp 2012 directors: 12 board size: 16.0 company index: 82
# Too high: bank of america corp 2013 directors: 19 board size: 15.0 company index: 82
# Too low: bank of america corp 2014 directors: 14 board size: 15.0 company index: 82
# Too high: bank of america corp 2015 directors: 15 board size: 14.0 company index: 82
# Too high: baxter international inc 2011 directors: 13 board size: 12.0 company index: 83
# Too high: baxter international inc 2015 directors: 14 board size: 12.0 company index: 83
# Too high: best buy co inc 2012 directors: 14 board size: 13.0 company index: 85
# Too low: best buy co inc 2014 directors: 10 board size: 11.0 company index: 85
# Too low: best buy co inc 2015 directors: 11 board size: 12.0 company index: 85
# Too high: becton dickinson and co 2012 directors: 15 board size: 14.0 company index: 86
# Too low: becton dickinson and co 2013 directors: 14 board size: 15.0 company index: 86
# Too high: franklin resources inc 2011 directors: 13 board size: 12.0 company index: 87
# Missing start date 2012 franklin resources inc
# Too high: franklin resources inc 2014 directors: 9 board size: 8.0 company index: 87
# Missing start date 2015 franklin resources inc
# Too low: brown-forman corp 2012 directors: 11 board size: 12.0 company index: 88
# Too low: brown-forman corp 2013 directors: 10 board size: 11.0 company index: 88
# Too low: brown-forman corp 2014 directors: 10 board size: 11.0 company index: 88
# Too high: brown-forman corp 2015 directors: 13 board size: 11.0 company index: 88
# Too high: biogen inc 2014 directors: 12 board size: 11.0 company index: 89
# Too high: bank of new york mellon corp 2011 directors: 16 board size: 14.0 company index: 90
# Too high: bank of new york mellon corp 2012 directors: 14 board size: 13.0 company index: 90
# Too high: bank of new york mellon corp 2013 directors: 13 board size: 12.0 company index: 90
# Too high: bank of new york mellon corp 2014 directors: 16 board size: 15.0 company index: 90
# Too high: bank of new york mellon corp 2015 directors: 16 board size: 15.0 company index: 90
# Too low: booking holdings inc 2011 directors: 7 board size: 9.0 company index: 91
# Too low: booking holdings inc 2012 directors: 7 board size: 9.0 company index: 91
# Too low: booking holdings inc 2013 directors: 9 board size: 10.0 company index: 91
# Too low: booking holdings inc 2014 directors: 9 board size: 11.0 company index: 91
# Too low: booking holdings inc 2015 directors: 10 board size: 12.0 company index: 91
# Missing start date 2011 baker hughes co
# Missing start date 2012 baker hughes co
# Missing start date 2013 baker hughes co
# Missing start date 2014 baker hughes co
# Missing start date 2015 baker hughes co
# Too high: blackrock inc 2011 directors: 20 board size: 17.0 company index: 93
# Too low: blackrock inc 2012 directors: 18 board size: 19.0 company index: 93
# Too high: blackrock inc 2014 directors: 20 board size: 18.0 company index: 93
# Too low: ball corp 2011 directors: 10 board size: 11.0 company index: 94
# Too low: ball corp 2012 directors: 10 board size: 11.0 company index: 94
# Too high: ball corp 2013 directors: 11 board size: 10.0 company index: 94
# Too low: ball corp 2014 directors: 10 board size: 11.0 company index: 94
# Too high: ball corp 2015 directors: 11 board size: 9.0 company index: 94
# Too high: bristol-myers squibb co 2011 directors: 12 board size: 11.0 company index: 95
# Too high: bristol-myers squibb co 2013 directors: 13 board size: 10.0 company index: 95
# Too low: bristol-myers squibb co 2014 directors: 11 board size: 12.0 company index: 95
# Too low: brookfield property reit inc 2012 directors: 8 board size: 9.0 company index: 96
# Too low: brookfield property reit inc 2014 directors: 7 board size: 9.0 company index: 96
# Too low: brookfield property reit inc 2015 directors: 7 board size: 9.0 company index: 96
# Too low: berkshire hathaway inc 2011 directors: 12 board size: 13.0 company index: 97
# Too low: berkshire hathaway inc 2012 directors: 12 board size: 13.0 company index: 97
# Too low: berkshire hathaway inc 2014 directors: 13 board size: 14.0 company index: 97
# Too low: berkshire hathaway inc 2015 directors: 12 board size: 13.0 company index: 97
# Too high: boston scientific corp 2011 directors: 14 board size: 11.0 company index: 98
# Too high: boston scientific corp 2012 directors: 11 board size: 10.0 company index: 98
# Too low: boston scientific corp 2013 directors: 9 board size: 10.0 company index: 98
# Too high: boston scientific corp 2015 directors: 13 board size: 12.0 company index: 98
# Too high: borgwarner inc 2013 directors: 13 board size: 11.0 company index: 99
# Too high: borgwarner inc 2014 directors: 12 board size: 11.0 company index: 99
# Too high: borgwarner inc 2015 directors: 11 board size: 10.0 company index: 99
# Too high: boston properties inc 2012 directors: 10 board size: 9.0 company index: 100
# Too high: boston properties inc 2014 directors: 12 board size: 11.0 company index: 100
# Too high: conagra brands inc 2015 directors: 15 board size: 12.0 company index: 101
# Too high: citigroup inc 2011 directors: 15 board size: 13.0 company index: 102
# Too high: citigroup inc 2012 directors: 15 board size: 12.0 company index: 102
# Too high: citigroup inc 2014 directors: 14 board size: 13.0 company index: 102
# Too high: citigroup inc 2015 directors: 15 board size: 14.0 company index: 102
# Too high: cardinal health inc 2011 directors: 14 board size: 12.0 company index: 103
# Too high: cardinal health inc 2012 directors: 14 board size: 13.0 company index: 103
# Too high: cardinal health inc 2014 directors: 14 board size: 13.0 company index: 103
# Too high: caterpillar inc 2011 directors: 16 board size: 15.0 company index: 104
# Too low: chubb ltd 2011 directors: 13 board size: 14.0 company index: 105
# Too high: chubb ltd 2012 directors: 13 board size: 12.0 company index: 105
# Too low: chubb ltd 2013 directors: 11 board size: 12.0 company index: 105
# Too high: chubb ltd 2014 directors: 15 board size: 14.0 company index: 105
# Too low: chubb ltd 2015 directors: 13 board size: 14.0 company index: 105
# Too low: crown castle international corp 2011 directors: 10 board size: 11.0 company index: 106
# Too low: crown castle international corp 2013 directors: 9 board size: 10.0 company index: 106
# Too low: crown castle international corp 2014 directors: 10 board size: 11.0 company index: 106
# Too low: crown castle international corp 2015 directors: 11 board size: 12.0 company index: 106
# Too low: cbre group inc 2011 directors: 10 board size: 11.0 company index: 107
# Too low: cbre group inc 2012 directors: 10 board size: 12.0 company index: 107
# Too high: cbre group inc 2013 directors: 12 board size: 10.0 company index: 107
# Too low: cbre group inc 2015 directors: 10 board size: 11.0 company index: 107
# Missing start date 2011 coca-cola european partners plc
# Missing start date 2012 coca-cola european partners plc
# Missing start date 2013 coca-cola european partners plc
# Missing start date 2014 coca-cola european partners plc
# Missing start date 2015 coca-cola european partners plc
# Too low: carnival corp 2011 directors: 12 board size: 14.0 company index: 109
# Too low: carnival corp 2012 directors: 13 board size: 14.0 company index: 109
# Too high: carnival corp 2013 directors: 14 board size: 11.0 company index: 109
# Too high: carnival corp 2014 directors: 11 board size: 9.0 company index: 109
# Too high: carnival corp 2015 directors: 10 board size: 9.0 company index: 109
# Too low: cerner corp 2013 directors: 8 board size: 9.0 company index: 110
# Too high: cf industries holdings inc 2012 directors: 10 board size: 8.0 company index: 111
# Too high: church & dwight co inc 2011 directors: 11 board size: 10.0 company index: 112
# Too high: church & dwight co inc 2013 directors: 10 board size: 9.0 company index: 112
# Too high: church & dwight co inc 2014 directors: 10 board size: 9.0 company index: 112
# Too high: chesapeake energy corp 2012 directors: 14 board size: 10.0 company index: 113
# Too high: chesapeake energy corp 2013 directors: 12 board size: 10.0 company index: 113
# Missing start date 2015 chesapeake energy corp
# Too high: ch robinson worldwide inc 2011 directors: 9 board size: 8.0 company index: 114
# Too low: ch robinson worldwide inc 2012 directors: 9 board size: 10.0 company index: 114
# Too high: ch robinson worldwide inc 2013 directors: 11 board size: 10.0 company index: 114
# Too high: ch robinson worldwide inc 2015 directors: 10 board size: 9.0 company index: 114
# Missing start date 2011 cigna corp
# Missing start date 2012 cigna corp
# Missing start date 2013 cigna corp
# Missing start date 2014 cigna corp
# Missing start date 2015 cigna corp
# Too low: cincinnati financial corp 2011 directors: 14 board size: 15.0 company index: 116
# Too low: cincinnati financial corp 2012 directors: 14 board size: 15.0 company index: 116
# Too low: cincinnati financial corp 2013 directors: 14 board size: 16.0 company index: 116
# Too low: cincinnati financial corp 2015 directors: 14 board size: 15.0 company index: 116
# Too high: colgate-palmolive co 2011 directors: 10 board size: 9.0 company index: 117
# Too high: colgate-palmolive co 2014 directors: 12 board size: 11.0 company index: 117
# Too high: colgate-palmolive co 2015 directors: 13 board size: 11.0 company index: 117
# Too high: cleveland-cliffs inc 2011 directors: 13 board size: 12.0 company index: 118
# Too high: cleveland-cliffs inc 2012 directors: 12 board size: 10.0 company index: 118
# Too high: cleveland-cliffs inc 2013 directors: 14 board size: 11.0 company index: 118
# Too high: cleveland-cliffs inc 2014 directors: 18 board size: 9.0 company index: 118
# Too high: clorox co 2015 directors: 12 board size: 10.0 company index: 119
# Too high: comerica inc 2011 directors: 10 board size: 9.0 company index: 120
# Too high: comcast corp 2011 directors: 15 board size: 12.0 company index: 121
# Too high: comcast corp 2015 directors: 12 board size: 11.0 company index: 121
# Too high: cme group inc 2011 directors: 37 board size: 36.0 company index: 122
# Too high: cme group inc 2012 directors: 36 board size: 33.0 company index: 122
# Too high: cme group inc 2013 directors: 33 board size: 30.0 company index: 122
# Too high: cme group inc 2014 directors: 33 board size: 28.0 company index: 122
# Too high: cme group inc 2015 directors: 33 board size: 28.0 company index: 122
# Too high: chipotle mexican grill inc 2014 directors: 9 board size: 8.0 company index: 123
# Too low: cummins inc 2011 directors: 9 board size: 10.0 company index: 124
# Too high: cummins inc 2013 directors: 9 board size: 8.0 company index: 124
# Too high: cms energy corp 2013 directors: 12 board size: 11.0 company index: 125
# Too high: cms energy corp 2015 directors: 14 board size: 12.0 company index: 125
# Too high: centerpoint energy inc 2011 directors: 12 board size: 10.0 company index: 126
# Too low: centerpoint energy inc 2012 directors: 9 board size: 10.0 company index: 126
# Too high: centerpoint energy inc 2013 directors: 10 board size: 8.0 company index: 126
# Too high: centerpoint energy inc 2015 directors: 11 board size: 10.0 company index: 126
# Too high: cnx resources corp 2013 directors: 12 board size: 11.0 company index: 127
# Missing start date 2014 cnx resources corp
# Too high: cnx resources corp 2015 directors: 12 board size: 11.0 company index: 127
# Too high: capital one financial corp 2011 directors: 10 board size: 9.0 company index: 128
# Too high: capital one financial corp 2012 directors: 12 board size: 10.0 company index: 128
# Too high: capital one financial corp 2013 directors: 12 board size: 11.0 company index: 128
# Too high: cabot oil & gas corp 2012 directors: 9 board size: 7.0 company index: 129
# Too high: conocophillips 2011 directors: 15 board size: 14.0 company index: 130
# Too high: conocophillips 2012 directors: 16 board size: 10.0 company index: 130
# Too high: conocophillips 2013 directors: 11 board size: 9.0 company index: 130
# Too high: conocophillips 2015 directors: 12 board size: 11.0 company index: 130
# Missing start date 2011 costco wholesale corp
# Missing start date 2012 costco wholesale corp
# Missing start date 2013 costco wholesale corp
# Missing start date 2014 costco wholesale corp
# Missing start date 2015 costco wholesale corp
# Too high: campbell soup co 2011 directors: 18 board size: 17.0 company index: 132
# Missing start date 2013 capri holdings ltd
# Missing start date 2014 capri holdings ltd
# Missing start date 2015 capri holdings ltd
# Too high: salesforce.com inc 2013 directors: 10 board size: 9.0 company index: 134
# Too high: salesforce.com inc 2014 directors: 11 board size: 10.0 company index: 134
# Too high: cisco systems inc 2011 directors: 13 board size: 12.0 company index: 135
# Too high: cisco systems inc 2012 directors: 14 board size: 12.0 company index: 135
# Too low: cisco systems inc 2015 directors: 10 board size: 11.0 company index: 135
# Missing start date 2012 csx corp
# Missing start date 2013 csx corp
# Too high: e i du pont de nemours and co 2011 directors: 12 board size: 11.0 company index: 137
# Too high: e i du pont de nemours and co 2012 directors: 12 board size: 11.0 company index: 137
# Too low: e i du pont de nemours and co 2013 directors: 11 board size: 12.0 company index: 137
# Too high: e i du pont de nemours and co 2015 directors: 14 board size: 11.0 company index: 137
# Too low: cognizant technology solutions corp 2012 directors: 8 board size: 10.0 company index: 139
# Too low: cognizant technology solutions corp 2013 directors: 9 board size: 10.0 company index: 139
# Too high: cognizant technology solutions corp 2014 directors: 10 board size: 9.0 company index: 139
# Too low: cognizant technology solutions corp 2015 directors: 9 board size: 10.0 company index: 139
# Too low: citrix systems inc 2014 directors: 10 board size: 11.0 company index: 140
# Too high: citrix systems inc 2015 directors: 12 board size: 10.0 company index: 140
# Too high: cvs health corp 2011 directors: 15 board size: 12.0 company index: 141
# Too high: cvs health corp 2012 directors: 12 board size: 10.0 company index: 141
# Too high: cvs health corp 2013 directors: 11 board size: 9.0 company index: 141
# Too high: chevron corp 2011 directors: 16 board size: 13.0 company index: 142
# Too high: chevron corp 2012 directors: 14 board size: 12.0 company index: 142
# Too high: chevron corp 2013 directors: 12 board size: 11.0 company index: 142
# Too low: chevron corp 2014 directors: 12 board size: 13.0 company index: 142
# Too high: chevron corp 2015 directors: 13 board size: 12.0 company index: 142
# Too low: dominion energy inc 2011 directors: 11 board size: 12.0 company index: 143
# Too high: dominion energy inc 2012 directors: 12 board size: 10.0 company index: 143
# Too low: dominion energy inc 2013 directors: 11 board size: 12.0 company index: 143
# Too low: delta air lines inc 2012 directors: 12 board size: 14.0 company index: 144
# Too low: delta air lines inc 2013 directors: 13 board size: 14.0 company index: 144
# Too low: delta air lines inc 2014 directors: 14 board size: 16.0 company index: 144
# Too high: delta air lines inc 2015 directors: 18 board size: 15.0 company index: 144
# Too high: deere & co 2014 directors: 12 board size: 11.0 company index: 145
# Too low: discover financial services 2011 directors: 10 board size: 11.0 company index: 146
# Too low: discover financial services 2012 directors: 10 board size: 11.0 company index: 146
# Less than one year term: 2014 discover financial services
# Too low: discover financial services 2015 directors: 10 board size: 11.0 company index: 146
# Too high: dollar general corp 2012 directors: 8 board size: 7.0 company index: 147
# Too high: dollar general corp 2014 directors: 8 board size: 7.0 company index: 147
# Too high: dollar general corp 2015 directors: 9 board size: 8.0 company index: 147
# Too low: quest diagnostics inc 2013 directors: 8 board size: 9.0 company index: 148
# Too low: quest diagnostics inc 2015 directors: 10 board size: 11.0 company index: 148
# Too high: d.r. horton inc 2014 directors: 7 board size: 6.0 company index: 149
# Too low: danaher corp 2011 directors: 10 board size: 11.0 company index: 150
# Too high: danaher corp 2013 directors: 11 board size: 10.0 company index: 150
# Too high: danaher corp 2014 directors: 11 board size: 10.0 company index: 150
# Missing start date 2011 walt disney co
# Missing start date 2012 walt disney co
# Missing start date 2013 walt disney co
# Missing start date 2014 walt disney co
# Missing start date 2015 walt disney co
# Too high: discovery inc 2014 directors: 11 board size: 10.0 company index: 152
# Too low: dollar tree inc 2011 directors: 10 board size: 11.0 company index: 153
# Too low: dollar tree inc 2012 directors: 10 board size: 11.0 company index: 153
# Too low: dollar tree inc 2013 directors: 10 board size: 11.0 company index: 153
# Too low: dollar tree inc 2014 directors: 10 board size: 11.0 company index: 153
# Too high: dover corp 2011 directors: 13 board size: 12.0 company index: 154
# Too high: dover corp 2014 directors: 13 board size: 12.0 company index: 154
# Too low: dover corp 2015 directors: 12 board size: 13.0 company index: 154
# Too high: diamond offshore drilling inc 2011 directors: 11 board size: 10.0 company index: 155
# Too low: diamond offshore drilling inc 2015 directors: 10 board size: 11.0 company index: 155
# Too high: darden restaurants inc 2012 directors: 15 board size: 13.0 company index: 156
# Too high: darden restaurants inc 2014 directors: 20 board size: 13.0 company index: 156
# Too low: darden restaurants inc 2015 directors: 13 board size: 14.0 company index: 156
# Too high: dte energy co 2011 directors: 14 board size: 13.0 company index: 157
# Too high: dte energy co 2013 directors: 14 board size: 13.0 company index: 157
# Too high: dte energy co 2015 directors: 13 board size: 12.0 company index: 157
# Less than one year term: 2012 duke energy corp
# Too low: duke energy corp 2013 directors: 16 board size: 17.0 company index: 158
# Too high: duke energy corp 2014 directors: 16 board size: 15.0 company index: 158
# Too high: duke energy corp 2015 directors: 16 board size: 15.0 company index: 158
# Too low: davita inc 2011 directors: 9 board size: 10.0 company index: 159
# Too low: davita inc 2013 directors: 9 board size: 10.0 company index: 159
# Too low: davita inc 2014 directors: 9 board size: 10.0 company index: 159
# Too low: davita inc 2015 directors: 9 board size: 11.0 company index: 159
# Too low: devon energy corp 2011 directors: 8 board size: 9.0 company index: 160
# Too low: devon energy corp 2012 directors: 7 board size: 9.0 company index: 160
# Too low: devon energy corp 2013 directors: 7 board size: 9.0 company index: 160
# Too low: devon energy corp 2014 directors: 9 board size: 11.0 company index: 160
# Too low: devon energy corp 2015 directors: 9 board size: 10.0 company index: 160
# Missing start date 2011 dxc technology co
# Missing start date 2012 dxc technology co
# Missing start date 2013 dxc technology co
# Missing start date 2014 dxc technology co
# Missing start date 2015 dxc technology co
# Too high: electronic arts inc 2013 directors: 10 board size: 8.0 company index: 162
# Too high: ebay inc 2012 directors: 13 board size: 12.0 company index: 163
# Too high: ebay inc 2013 directors: 13 board size: 11.0 company index: 163
# Too high: ebay inc 2014 directors: 13 board size: 11.0 company index: 163
# Less than one year term: 2015 ebay inc
# Too low: ecolab inc 2011 directors: 13 board size: 14.0 company index: 164
# Too high: ecolab inc 2012 directors: 14 board size: 13.0 company index: 164
# Too high: ecolab inc 2013 directors: 15 board size: 14.0 company index: 164
# Too low: ecolab inc 2015 directors: 15 board size: 17.0 company index: 164
# Too high: consolidated edison inc 2012 directors: 13 board size: 12.0 company index: 165
# Too high: consolidated edison inc 2014 directors: 14 board size: 11.0 company index: 165
# Too high: consolidated edison inc 2015 directors: 12 board size: 10.0 company index: 165
# Too low: equifax inc 2013 directors: 9 board size: 10.0 company index: 166
# Too low: edison international 2011 directors: 12 board size: 13.0 company index: 167
# Too high: edison international 2012 directors: 13 board size: 12.0 company index: 167
# Too high: edison international 2013 directors: 13 board size: 12.0 company index: 167
# Too high: edison international 2014 directors: 13 board size: 12.0 company index: 167
# Too high: edison international 2015 directors: 12 board size: 10.0 company index: 167
# Too low: estee lauder companies inc 2011 directors: 14 board size: 16.0 company index: 168
# Too low: estee lauder companies inc 2012 directors: 14 board size: 16.0 company index: 168
# Too low: estee lauder companies inc 2013 directors: 14 board size: 16.0 company index: 168
# Too low: estee lauder companies inc 2014 directors: 14 board size: 16.0 company index: 168
# Too low: estee lauder companies inc 2015 directors: 14 board size: 16.0 company index: 168
# Too high: eastman chemical co 2011 directors: 13 board size: 12.0 company index: 169
# Too low: eastman chemical co 2013 directors: 12 board size: 13.0 company index: 169
# Too high: eastman chemical co 2014 directors: 12 board size: 11.0 company index: 169
# Too high: emerson electric co 2011 directors: 15 board size: 13.0 company index: 170
# Too low: emerson electric co 2012 directors: 14 board size: 15.0 company index: 170
# Too high: emerson electric co 2013 directors: 15 board size: 13.0 company index: 170
# Missing start date 2011 endo international plc
# Missing start date 2012 endo international plc
# Missing start date 2013 endo international plc
# Missing start date 2014 endo international plc
# Too high: eog resources inc 2014 directors: 8 board size: 7.0 company index: 172
# Too low: equinix inc 2011 directors: 7 board size: 8.0 company index: 173
# Too low: equinix inc 2012 directors: 7 board size: 8.0 company index: 173
# Too low: equinix inc 2014 directors: 7 board size: 8.0 company index: 173
# Too low: equinix inc 2015 directors: 7 board size: 9.0 company index: 173
# Too low: equity residential 2011 directors: 10 board size: 11.0 company index: 174
# Too low: equity residential 2012 directors: 10 board size: 11.0 company index: 174
# Too low: equity residential 2013 directors: 10 board size: 11.0 company index: 174
# Too low: equity residential 2014 directors: 10 board size: 11.0 company index: 174
# Too low: equity residential 2015 directors: 11 board size: 13.0 company index: 174
# Too high: eqt corp 2012 directors: 13 board size: 11.0 company index: 175
# Too high: eversource energy 2012 directors: 18 board size: 14.0 company index: 176
# Too high: eversource energy 2013 directors: 14 board size: 13.0 company index: 176
# Too high: eversource energy 2015 directors: 13 board size: 12.0 company index: 176
# Too high: essex property trust inc 2011 directors: 12 board size: 10.0 company index: 177
# Too high: essex property trust inc 2015 directors: 13 board size: 12.0 company index: 177
# Too high: eaton corporation plc 2011 directors: 13 board size: 12.0 company index: 178
# Too high: entergy corp 2011 directors: 13 board size: 11.0 company index: 179
# Too high: entergy corp 2013 directors: 13 board size: 11.0 company index: 179
# Too high: edwards lifesciences corp 2015 directors: 9 board size: 8.0 company index: 180
# Too high: exelon corp 2011 directors: 16 board size: 15.0 company index: 181
# Too high: exelon corp 2012 directors: 21 board size: 18.0 company index: 181
# Too high: exelon corp 2013 directors: 18 board size: 15.0 company index: 181
# Too high: exelon corp 2014 directors: 16 board size: 14.0 company index: 181
# Too high: exelon corp 2015 directors: 15 board size: 14.0 company index: 181
# Too high: expeditors international of washington inc 2014 directors: 12 board size: 11.0 company index: 182
# Too low: expedia group inc 2011 directors: 8 board size: 10.0 company index: 183
# Too low: expedia group inc 2012 directors: 9 board size: 10.0 company index: 183
# Too low: expedia group inc 2013 directors: 8 board size: 10.0 company index: 183
# Too low: expedia group inc 2014 directors: 8 board size: 10.0 company index: 183
# Too low: expedia group inc 2015 directors: 9 board size: 13.0 company index: 183
# Too low: ford motor co 2011 directors: 14 board size: 15.0 company index: 184
# Too low: ford motor co 2012 directors: 15 board size: 16.0 company index: 184
# Too low: ford motor co 2013 directors: 16 board size: 17.0 company index: 184
# Too high: ford motor co 2014 directors: 17 board size: 16.0 company index: 184
# Too low: fastenal co 2011 directors: 8 board size: 10.0 company index: 185
# Too low: fastenal co 2012 directors: 10 board size: 12.0 company index: 185
# Too low: fastenal co 2013 directors: 10 board size: 12.0 company index: 185
# Too low: fastenal co 2015 directors: 9 board size: 10.0 company index: 185
# Too high: facebook inc 2013 directors: 9 board size: 8.0 company index: 186
# Too high: facebook inc 2015 directors: 9 board size: 8.0 company index: 186
# Too low: freeport-mcmoran inc 2011 directors: 11 board size: 12.0 company index: 187
# Too low: freeport-mcmoran inc 2012 directors: 11 board size: 12.0 company index: 187
# Too low: freeport-mcmoran inc 2013 directors: 13 board size: 15.0 company index: 187
# Too low: freeport-mcmoran inc 2014 directors: 14 board size: 15.0 company index: 187
# Too high: freeport-mcmoran inc 2015 directors: 16 board size: 10.0 company index: 187
# Too low: fedex corp 2011 directors: 10 board size: 11.0 company index: 188
# Too low: fedex corp 2012 directors: 11 board size: 12.0 company index: 188
# Too low: fedex corp 2013 directors: 11 board size: 12.0 company index: 188
# Too low: fedex corp 2014 directors: 12 board size: 13.0 company index: 188
# Too low: fedex corp 2015 directors: 11 board size: 12.0 company index: 188
# Too low: firstenergy corp 2011 directors: 13 board size: 14.0 company index: 189
# Too high: firstenergy corp 2012 directors: 15 board size: 14.0 company index: 189
# Too low: firstenergy corp 2013 directors: 14 board size: 15.0 company index: 189
# Too high: firstenergy corp 2014 directors: 15 board size: 14.0 company index: 189
# Too high: firstenergy corp 2015 directors: 16 board size: 13.0 company index: 189
# Too high: f5 networks inc 2011 directors: 8 board size: 7.0 company index: 190
# Too high: f5 networks inc 2012 directors: 7 board size: 5.0 company index: 190
# Too high: federated hermes inc 2011 directors: 8 board size: 7.0 company index: 191
# Too high: federated hermes inc 2014 directors: 8 board size: 7.0 company index: 191
# Too high: federated hermes inc 2015 directors: 7 board size: 6.0 company index: 191
# Too low: first horizon national corp 2011 directors: 12 board size: 13.0 company index: 192
# Too high: first horizon national corp 2012 directors: 13 board size: 11.0 company index: 192
# Too low: first horizon national corp 2013 directors: 10 board size: 11.0 company index: 192
# Too low: first horizon national corp 2014 directors: 10 board size: 12.0 company index: 192
# Too low: fidelity national information services inc 2014 directors: 10 board size: 11.0 company index: 193
# Too low: fidelity national information services inc 2015 directors: 10 board size: 11.0 company index: 193
# Less than one year term: 2011 fiserv inc
# Too low: fiserv inc 2013 directors: 9 board size: 10.0 company index: 194
# Too low: fiserv inc 2014 directors: 9 board size: 10.0 company index: 194
# Too low: fiserv inc 2015 directors: 10 board size: 11.0 company index: 194
# Too low: fifth third bancorp 2013 directors: 14 board size: 15.0 company index: 195
# Too high: fifth third bancorp 2014 directors: 15 board size: 13.0 company index: 195
# Too high: fluor corp 2011 directors: 13 board size: 12.0 company index: 196
# Too high: fluor corp 2014 directors: 16 board size: 14.0 company index: 196
# Too high: fluor corp 2015 directors: 14 board size: 13.0 company index: 196
# Too high: flowserve corp 2013 directors: 12 board size: 11.0 company index: 197
# Too high: flowserve corp 2015 directors: 12 board size: 11.0 company index: 197
# Too low: fmc corp 2013 directors: 9 board size: 11.0 company index: 198
# Too low: fmc corp 2015 directors: 9 board size: 10.0 company index: 198
# Too low: fossil group inc 2011 directors: 9 board size: 10.0 company index: 199
# Too low: fossil group inc 2014 directors: 10 board size: 11.0 company index: 199
# Too high: first solar inc 2011 directors: 9 board size: 8.0 company index: 200
# Too high: first solar inc 2012 directors: 11 board size: 10.0 company index: 200
# Too high: frontier communications corp 2011 directors: 13 board size: 11.0 company index: 201
# Too high: frontier communications corp 2014 directors: 13 board size: 12.0 company index: 201
# Too low: general dynamics corp 2011 directors: 12 board size: 13.0 company index: 202
# Too low: general dynamics corp 2012 directors: 12 board size: 13.0 company index: 202
# Too low: general dynamics corp 2014 directors: 12 board size: 13.0 company index: 202
# Too high: general electric co 2011 directors: 17 board size: 16.0 company index: 203
# Too high: general electric co 2013 directors: 21 board size: 18.0 company index: 203
# Too high: general electric co 2014 directors: 18 board size: 17.0 company index: 203
# Too high: general electric co 2015 directors: 17 board size: 16.0 company index: 203
# Too high: gilead sciences inc 2011 directors: 13 board size: 12.0 company index: 204
# Too high: gilead sciences inc 2013 directors: 12 board size: 10.0 company index: 204
# Too low: graham holdings co 2013 directors: 10 board size: 11.0 company index: 205
# Too low: graham holdings co 2014 directors: 10 board size: 12.0 company index: 205
# Too low: graham holdings co 2015 directors: 11 board size: 12.0 company index: 205
# Too high: general mills inc 2011 directors: 14 board size: 13.0 company index: 206
# Too high: general mills inc 2014 directors: 14 board size: 13.0 company index: 206
# Too low: globe life inc 2012 directors: 10 board size: 12.0 company index: 207
# Too high: globe life inc 2014 directors: 12 board size: 11.0 company index: 207
# Too low: corning inc 2011 directors: 13 board size: 14.0 company index: 208
# Too high: corning inc 2012 directors: 14 board size: 13.0 company index: 208
# Too high: corning inc 2013 directors: 14 board size: 13.0 company index: 208
# ...
# Too low: tenet healthcare corp 2014 directors: 9 board size: 10.0 company index: 424
# Too low: tenet healthcare corp 2015 directors: 9 board size: 10.0 company index: 424
# Too low: tjx companies inc 2011 directors: 9 board size: 11.0 company index: 425
# Too low: tjx companies inc 2012 directors: 8 board size: 9.0 company index: 425
# Too low: tjx companies inc 2013 directors: 9 board size: 10.0 company index: 425
# Too low: tjx companies inc 2014 directors: 9 board size: 11.0 company index: 425
# Too low: tjx companies inc 2015 directors: 9 board size: 10.0 company index: 425
# Too low: thermo fisher scientific inc 2011 directors: 11 board size: 12.0 company index: 426
# Too high: thermo fisher scientific inc 2012 directors: 12 board size: 11.0 company index: 426
# Too low: thermo fisher scientific inc 2013 directors: 10 board size: 11.0 company index: 426
# Too low: thermo fisher scientific inc 2014 directors: 10 board size: 11.0 company index: 426
# Too low: thermo fisher scientific inc 2015 directors: 10 board size: 11.0 company index: 426
# Missing start date 2011 t-mobile us inc
# Missing start date 2012 t-mobile us inc
# Less than one year term: 2013 t-mobile us inc
# Too high: t-mobile us inc 2014 directors: 12 board size: 11.0 company index: 427
# Too high: tapestry inc 2012 directors: 8 board size: 7.0 company index: 428
# Too high: tapestry inc 2014 directors: 11 board size: 10.0 company index: 428
# Too low: tripadvisor inc 2011 directors: 7 board size: 10.0 company index: 429
# Too high: tripadvisor inc 2013 directors: 13 board size: 9.0 company index: 429
# Too high: tripadvisor inc 2015 directors: 9 board size: 8.0 company index: 429
# Too low: t. rowe price group inc 2012 directors: 10 board size: 11.0 company index: 430
# Too low: t. rowe price group inc 2015 directors: 14 board size: 15.0 company index: 430
# Too high: travelers companies inc 2011 directors: 13 board size: 12.0 company index: 431
# Too high: travelers companies inc 2013 directors: 13 board size: 12.0 company index: 431
# Too low: travelers companies inc 2015 directors: 13 board size: 14.0 company index: 431
# Too high: tractor supply co 2011 directors: 10 board size: 9.0 company index: 432
# Too low: tractor supply co 2013 directors: 8 board size: 9.0 company index: 432
# Too low: tractor supply co 2014 directors: 8 board size: 9.0 company index: 432
# Too high: tyson foods inc 2011 directors: 10 board size: 8.0 company index: 433
# Too high: tyson foods inc 2012 directors: 10 board size: 9.0 company index: 433
# Too high: tyson foods inc 2013 directors: 10 board size: 9.0 company index: 433
# Too high: tyson foods inc 2014 directors: 11 board size: 9.0 company index: 433
# Too high: tyson foods inc 2015 directors: 12 board size: 9.0 company index: 433
# Too high: trane technologies plc 2011 directors: 12 board size: 11.0 company index: 434
# Too high: trane technologies plc 2013 directors: 13 board size: 12.0 company index: 434
# Too high: trane technologies plc 2014 directors: 12 board size: 11.0 company index: 434
# Too high: trane technologies plc 2015 directors: 14 board size: 12.0 company index: 434
# Too high: texas instruments inc 2011 directors: 11 board size: 10.0 company index: 435
# Too low: texas instruments inc 2013 directors: 9 board size: 11.0 company index: 435
# Too low: texas instruments inc 2014 directors: 10 board size: 11.0 company index: 435
# Too low: texas instruments inc 2015 directors: 11 board size: 12.0 company index: 435
# Too high: textron inc 2011 directors: 13 board size: 12.0 company index: 436
# Too high: textron inc 2012 directors: 12 board size: 11.0 company index: 436
# Too low: under armour inc 2011 directors: 7 board size: 8.0 company index: 437
# Too low: under armour inc 2012 directors: 9 board size: 10.0 company index: 437
# Too low: under armour inc 2014 directors: 9 board size: 11.0 company index: 437
# Too high: united airlines holdings inc 2012 directors: 15 board size: 13.0 company index: 438
# Too low: universal health services inc 2012 directors: 5 board size: 7.0 company index: 439
# Too low: universal health services inc 2013 directors: 6 board size: 7.0 company index: 439
# Too low: universal health services inc 2014 directors: 5 board size: 7.0 company index: 439
# Too low: universal health services inc 2015 directors: 5 board size: 7.0 company index: 439
# Too low: unitedhealth group inc 2011 directors: 9 board size: 10.0 company index: 440
# Too low: unitedhealth group inc 2012 directors: 10 board size: 11.0 company index: 440
# Too low: unitedhealth group inc 2013 directors: 10 board size: 11.0 company index: 440
# Too low: unitedhealth group inc 2014 directors: 10 board size: 11.0 company index: 440
# Too high: unum group 2011 directors: 12 board size: 11.0 company index: 441
# Too low: unum group 2012 directors: 11 board size: 12.0 company index: 441
# Too low: unum group 2013 directors: 12 board size: 13.0 company index: 441
# Too high: unum group 2014 directors: 14 board size: 13.0 company index: 441
# Too high: unum group 2015 directors: 16 board size: 15.0 company index: 441
# Too high: union pacific corp 2014 directors: 14 board size: 11.0 company index: 442
# Too high: union pacific corp 2015 directors: 11 board size: 10.0 company index: 442
# Too low: united parcel service inc 2011 directors: 11 board size: 12.0 company index: 443
# Too low: united parcel service inc 2012 directors: 12 board size: 13.0 company index: 443
# Too low: united parcel service inc 2014 directors: 14 board size: 15.0 company index: 443
# Too low: united parcel service inc 2015 directors: 11 board size: 12.0 company index: 443
# Too low: urban outfitters inc 2013 directors: 5 board size: 6.0 company index: 444
# Too low: urban outfitters inc 2014 directors: 5 board size: 7.0 company index: 444
# Too low: urban outfitters inc 2015 directors: 6 board size: 8.0 company index: 444
# Missing start date 2014 united rentals inc
# Missing start date 2015 united rentals inc
# Too high: u.s. bancorp 2012 directors: 16 board size: 15.0 company index: 446
# Too low: u.s. bancorp 2014 directors: 16 board size: 17.0 company index: 446
# Too high: u.s. bancorp 2015 directors: 19 board size: 17.0 company index: 446
# Too high: visa inc 2011 directors: 16 board size: 12.0 company index: 447
# Missing start date 2012 visa inc
# Missing start date 2014 visa inc
# Missing start date 2015 visa inc
# Too high: vf corp 2012 directors: 12 board size: 11.0 company index: 448
# Too high: vf corp 2015 directors: 13 board size: 12.0 company index: 448
# Too low: viacomcbs inc 2011 directors: 14 board size: 15.0 company index: 449
# Too low: viacomcbs inc 2012 directors: 14 board size: 15.0 company index: 449
# Too low: viacomcbs inc 2013 directors: 14 board size: 15.0 company index: 449
# Too low: viacomcbs inc 2014 directors: 14 board size: 15.0 company index: 449
# Too low: viacomcbs inc 2015 directors: 14 board size: 15.0 company index: 449
# Too high: varian medical systems inc 2012 directors: 11 board size: 10.0 company index: 450
# Too low: varian medical systems inc 2015 directors: 9 board size: 10.0 company index: 450
# Too high: viavi solutions inc 2015 directors: 9 board size: 5.0 company index: 451
# Too high: valero energy corp 2013 directors: 13 board size: 12.0 company index: 452
# Too high: valero energy corp 2014 directors: 12 board size: 10.0 company index: 452
# Too low: valero energy corp 2015 directors: 9 board size: 10.0 company index: 452
# Too high: vulcan materials co 2011 directors: 12 board size: 11.0 company index: 453
# Too high: vulcan materials co 2012 directors: 11 board size: 10.0 company index: 453
# Too high: vulcan materials co 2014 directors: 14 board size: 13.0 company index: 453
# Too high: vulcan materials co 2015 directors: 13 board size: 12.0 company index: 453
# Too low: vornado realty trust 2011 directors: 8 board size: 10.0 company index: 454
# Too low: vornado realty trust 2012 directors: 9 board size: 10.0 company index: 454
# Too low: vornado realty trust 2013 directors: 9 board size: 10.0 company index: 454
# Too low: vornado realty trust 2015 directors: 8 board size: 9.0 company index: 454
# Too high: verisk analytics inc 2013 directors: 12 board size: 11.0 company index: 455
# Too high: verisk analytics inc 2015 directors: 12 board size: 11.0 company index: 455
# Too low: verisign inc 2012 directors: 6 board size: 7.0 company index: 456
# Too low: verisign inc 2013 directors: 6 board size: 7.0 company index: 456
# Too low: verisign inc 2014 directors: 6 board size: 7.0 company index: 456
# Too low: verisign inc 2015 directors: 7 board size: 8.0 company index: 456
# Too high: vertex pharmaceuticals inc 2011 directors: 10 board size: 9.0 company index: 457
# Too low: vertex pharmaceuticals inc 2012 directors: 8 board size: 10.0 company index: 457
# Too low: vertex pharmaceuticals inc 2013 directors: 8 board size: 9.0 company index: 457
# Too low: vertex pharmaceuticals inc 2014 directors: 8 board size: 10.0 company index: 457
# Too low: ventas inc 2011 directors: 12 board size: 13.0 company index: 458
# Too high: ventas inc 2012 directors: 12 board size: 11.0 company index: 458
# Too high: ventas inc 2014 directors: 12 board size: 11.0 company index: 458
# Too high: ventas inc 2015 directors: 11 board size: 10.0 company index: 458
# Too high: verizon communications inc 2011 directors: 14 board size: 13.0 company index: 459
# Too high: verizon communications inc 2012 directors: 13 board size: 12.0 company index: 459
# Too low: verizon communications inc 2013 directors: 13 board size: 14.0 company index: 459
# Too high: verizon communications inc 2014 directors: 14 board size: 11.0 company index: 459
# Too low: waters corp 2015 directors: 9 board size: 10.0 company index: 460
# Too low: walgreens boots alliance inc 2011 directors: 6 board size: 11.0 company index: 461
# Too low: walgreens boots alliance inc 2012 directors: 8 board size: 10.0 company index: 461
# Too low: walgreens boots alliance inc 2013 directors: 8 board size: 10.0 company index: 461
# Too low: walgreens boots alliance inc 2014 directors: 9 board size: 11.0 company index: 461
# Too high: walgreens boots alliance inc 2015 directors: 13 board size: 11.0 company index: 461
# Too high: western digital corp 2013 directors: 14 board size: 12.0 company index: 462
# Too high: western digital corp 2014 directors: 13 board size: 12.0 company index: 462
# Too low: wec energy group inc 2011 directors: 8 board size: 9.0 company index: 463
# Too low: wec energy group inc 2014 directors: 8 board size: 9.0 company index: 463
# Too low: wec energy group inc 2015 directors: 11 board size: 12.0 company index: 463
# Too high: welltower inc 2011 directors: 11 board size: 10.0 company index: 464
# Too high: welltower inc 2012 directors: 12 board size: 10.0 company index: 464
# Too high: welltower inc 2014 directors: 12 board size: 11.0 company index: 464
# Too high: welltower inc 2015 directors: 11 board size: 9.0 company index: 464
# Too high: wells fargo & co 2011 directors: 17 board size: 16.0 company index: 465
# Too high: wells fargo & co 2012 directors: 16 board size: 15.0 company index: 465
# Too high: wells fargo & co 2013 directors: 17 board size: 15.0 company index: 465
# Too high: wells fargo & co 2014 directors: 15 board size: 14.0 company index: 465
# Too high: whirlpool corp 2011 directors: 14 board size: 12.0 company index: 466
# Too high: whirlpool corp 2013 directors: 13 board size: 11.0 company index: 466
# Too low: whirlpool corp 2014 directors: 12 board size: 13.0 company index: 466
# Too high: waste management inc 2012 directors: 9 board size: 8.0 company index: 467
# Too high: waste management inc 2013 directors: 9 board size: 8.0 company index: 467
# Too low: waste management inc 2015 directors: 9 board size: 10.0 company index: 467
# Too high: williams companies inc 2011 directors: 14 board size: 11.0 company index: 468
# Too high: williams companies inc 2012 directors: 14 board size: 10.0 company index: 468
# Too low: walmart inc 2011 directors: 13 board size: 15.0 company index: 469
# Too low: walmart inc 2013 directors: 16 board size: 17.0 company index: 469
# Too low: walmart inc 2014 directors: 15 board size: 16.0 company index: 469
# Too high: walmart inc 2015 directors: 16 board size: 15.0 company index: 469
# Too high: western union co 2011 directors: 10 board size: 9.0 company index: 471
# Too high: western union co 2012 directors: 11 board size: 10.0 company index: 471
# Too high: western union co 2014 directors: 12 board size: 11.0 company index: 471
# Too high: western union co 2015 directors: 13 board size: 12.0 company index: 471
# Too high: weyerhaeuser co 2011 directors: 11 board size: 10.0 company index: 472
# Too high: weyerhaeuser co 2013 directors: 11 board size: 10.0 company index: 472
# Too high: weyerhaeuser co 2015 directors: 11 board size: 10.0 company index: 472
# Too low: wyndham destinations inc 2011 directors: 6 board size: 7.0 company index: 473
# Too low: wyndham destinations inc 2012 directors: 6 board size: 7.0 company index: 473
# Too low: wyndham destinations inc 2013 directors: 6 board size: 7.0 company index: 473
# Too low: wyndham destinations inc 2014 directors: 6 board size: 7.0 company index: 473
# Too low: wyndham destinations inc 2015 directors: 6 board size: 7.0 company index: 473
# Too low: wynn resorts ltd 2011 directors: 11 board size: 12.0 company index: 474
# Too high: wynn resorts ltd 2012 directors: 13 board size: 9.0 company index: 474
# Too high: wynn resorts ltd 2013 directors: 9 board size: 8.0 company index: 474
# Too low: wynn resorts ltd 2015 directors: 8 board size: 9.0 company index: 474
# Too high: united states steel corp 2011 directors: 12 board size: 11.0 company index: 475
# Too high: united states steel corp 2013 directors: 14 board size: 13.0 company index: 475
# Less than one year term: 2014 united states steel corp
# Too high: united states steel corp 2015 directors: 14 board size: 10.0 company index: 475
# Too low: cimarex energy co 2011 directors: 9 board size: 11.0 company index: 476
# Too low: cimarex energy co 2012 directors: 9 board size: 11.0 company index: 476
# Too low: cimarex energy co 2013 directors: 10 board size: 11.0 company index: 476
# Too low: cimarex energy co 2014 directors: 10 board size: 11.0 company index: 476
# Too low: cimarex energy co 2015 directors: 10 board size: 11.0 company index: 476
# Too low: xcel energy inc 2012 directors: 11 board size: 12.0 company index: 477
# Too low: xcel energy inc 2013 directors: 11 board size: 12.0 company index: 477
# Too high: xcel energy inc 2015 directors: 13 board size: 12.0 company index: 477
# Too high: xilinx inc 2011 directors: 11 board size: 10.0 company index: 478
# Too high: xilinx inc 2012 directors: 11 board size: 10.0 company index: 478
# Too high: xilinx inc 2013 directors: 11 board size: 9.0 company index: 478
# Too high: xilinx inc 2014 directors: 10 board size: 9.0 company index: 478
# Too high: xilinx inc 2015 directors: 10 board size: 9.0 company index: 478
# Too high: exxon mobil corp 2014 directors: 13 board size: 12.0 company index: 479
# Too high: exxon mobil corp 2015 directors: 13 board size: 12.0 company index: 479
# Too high: dentsply sirona inc 2015 directors: 11 board size: 10.0 company index: 480
# Missing start date 2011 xylem inc
# Missing start date 2012 xylem inc
# Too high: xylem inc 2013 directors: 11 board size: 10.0 company index: 482
# Too high: xylem inc 2015 directors: 11 board size: 10.0 company index: 482
# Too high: yum! brands inc 2012 directors: 14 board size: 12.0 company index: 483
# Too high: yum! brands inc 2015 directors: 14 board size: 13.0 company index: 483
# Too low: zimmer biomet holdings inc 2012 directors: 9 board size: 10.0 company index: 484
# Too high: zimmer biomet holdings inc 2013 directors: 11 board size: 10.0 company index: 484
# Too low: zions bancorporation na 2011 directors: 9 board size: 10.0 company index: 485
# Too low: zions bancorporation na 2012 directors: 9 board size: 10.0 company index: 485
# Too low: zions bancorporation na 2013 directors: 9 board size: 10.0 company index: 485
# Too high: zions bancorporation na 2014 directors: 12 board size: 11.0 company index: 485
# Too high: zoetis inc 2013 directors: 12 board size: 8.0 company index: 486

# %% [markdown]
# I think that Reuters incorrectly labeled the fields relating to the time as a director and as an executive. It seems like they mixed them up. Therefore, I will only focus on the executive_start and executive_end field.
#
# It also seems like pretty much every company has a different reported board size compared to its listed directors.
#
# When I look at the share of incorrect matches between board size and director number, only roughly a third of all company-year combinations include correct matches. If I consider a variance of 1, then about 80% are correct. I think it is reasonable to consider these variances of 1 as acceptable because some directors may only be on the board a couple of months and the board size - which relates to the size at the end of the fiscal year - does not capture them then.
#
# What I could also consider is predicting all biographies, and then really only focus on the ones that include social or environmental matters. If all of those are correct and the board size mostly matches the number of directors, then I should be fine as well.

# %%
# there are 489 companies and 5 years minus a couple of companies with some issues
# but roughly this amounts to a total of 2,445 potential entries in the too_high list
# the below number shows the portions of years with higher numbers of directors than board size
len(too_high)/2445
# Out:
# 0.29243353783231085

# %%
# the same can be done for the too_low list
len(too_low)/2445
# Out:
# 0.2519427402862986

# %%
# check whether there are directors that have the same start and end date
# indicating that they were not counted for the fiscal year end board size metric
count = 0
for i, company in enumerate(all_combined_dfs):
    df_temp = company[company[['executive_start','executive_end']].nunique(axis=1) == 1]
    if not df_temp.empty:
        count += 1
print(count)

# I implemented this in the function check_dir_size and this has an effect of around 1 %age point less issues
# Out:
# 92

# %%
# these cases I need to check manually to add missing start dates for directors
count = 0
for company in all_combined_dfs:
    missing_start_date = company[company['missing_start_date'] == 1][['name', 'last_position', 'executive_end', 'comp_name']]
    #for index, row in missing_start_date.iterrows():
    if any(int(x) > 2010 for x in list(missing_start_date['executive_end'])):
        print(missing_start_date)
        count += 1
print('This many companies had directors with missing start dates:', count)

# I implemented this in the function check_dir_size and this has an effect of around 5 %age point less issues
# Out:
#                     name  ... comp_name
# 12       ms. karen larue  ...   itt inc
# 14  mr. g. peter d'aloia  ...   itt inc
#
# [2 rows x 4 columns]
#                  name  ...                     comp_name
# 19  ms. ellen alemany  ...  citizens financial group inc
#
# [1 rows x 4 columns]
#                           name  ...               comp_name
# 5  mr. jaime ellertson , ph.d.  ...  e*trade financial corp
#
# [1 rows x 4 columns]
#                  name last_position executive_end comp_name
# 5   mr. timothy whall      director          2019   adt inc
# 10   mr. brett watson      director          2018   adt inc
#                name  ...    comp_name
# 11  mr. scott cisel  ...  ameren corp
#
# [1 rows x 4 columns]
#                name  ...                               comp_name
# 7  mr. devin murphy  ...  apartment investment and management co
# 9    mr. john rayis  ...  apartment investment and management co
#
# [2 rows x 4 columns]
#                       name         last_position executive_end     comp_name
# 5   mr. james diller , sr.  independent director          2019  broadcom inc
# 11         mr. lucien wong              director          2016  broadcom inc
#                         name  ...               comp_name
# 3  mr. charles johnson , cpa  ...  franklin resources inc
#
# [1 rows x 4 columns]
#                          name  ...        comp_name
# 14  mr. jeffrey (jeff) immelt  ...  baker hughes co
#
# [1 rows x 4 columns]
#                     name  ...                        comp_name
# 13  mr. john brock , iii  ...  coca-cola european partners plc
#
# [1 rows x 4 columns]
#                   name last_position executive_end               comp_name
# 3  mr. scott gieselman      director          2019  chesapeake energy corp
#                      name         last_position executive_end   comp_name
# 9  dr. jane henney , m.d.  independent director          2018  cigna corp
#              name               last_position executive_end           comp_name
# 31  john whitmire  vice chairman of the board          2011  cnx resources corp
#                          name  ...              comp_name
# 3         mr. john meisenbach  ...  costco wholesale corp
# 7       mr. jim (jim) sinegal  ...  costco wholesale corp
# 9  mr. jeffrey (jeff) brotman  ...  costco wholesale corp
#
# [3 rows x 4 columns]
#                              name  ...           comp_name
# 5                mr. michael kors  ...  capri holdings ltd
# 16                     silas chou  ...  capri holdings ltd
# 17  lawrence (stroll) strulovitch  ...  capri holdings ltd
#
# [3 rows x 4 columns]
#                             name  ... comp_name
# 13  mr. edward (ned) kelly , iii  ...  csx corp
#
# [1 rows x 4 columns]
#                   name         last_position executive_end       comp_name
# 3        mr. john chen  independent director          2019  walt disney co
# 4  mr. fred langhammer  independent director          2019  walt disney co
# 5     mr. aylwin lewis  independent director          2019  walt disney co
#                             name  ...          comp_name
# 14  mr. j. michael (mike) lawrie  ...  dxc technology co
# 28    ms. margaret (meg) whitman  ...  dxc technology co
# 29               mr. mark foster  ...  dxc technology co
#
# [3 rows x 4 columns]
#                   name  ...               comp_name
# 16  mr. rajiv de silva  ...  endo international plc
#
# [1 rows x 4 columns]
#                 name last_position executive_end               comp_name
# 11  mr. john nichols      director          2016  genworth financial inc
#                   name  ...                comp_name
# 7  mr. timothy o'neill  ...  goldman sachs group inc
#
# [1 rows x 4 columns]
#                       name last_position executive_end          comp_name
# 20  mr. vincent (vin) ryan      director          2014  iron mountain inc
#               name  ...                      comp_name
# 18  michael sorkin  ...  jefferies financial group inc
#
# [1 rows x 4 columns]
#             name         last_position executive_end   comp_name
# 5  ms. nina vaca  independent director          2019  kohls corp
#                          name  ...                     comp_name
# 36  mr. jeffrey (jeff) serota  ...  lyondellbasell industries nv
#
# [1 rows x 4 columns]
#                  name  ...   comp_name
# 24  mr. antony spring  ...  macy's inc
#
# [1 rows x 4 columns]
#                name  ...                comp_name
# 21  mr. charles lee  ...  marathon petroleum corp
#
# [1 rows x 4 columns]
#                             name  ...            comp_name
# 22  dr. alberto calderon , ph.d.  ...  newmont corporation
#
# [1 rows x 4 columns]
#                      name  ...             comp_name
# 13  mr. james (jim) kilts  ...  nielsen holdings plc
#
# [1 rows x 4 columns]
#                name last_position executive_end  comp_name
# 42  mr. jeh johnson      director          2017  pg&e corp
#                name  ...            comp_name
# 21  mr. marc coucke  ...  perrigo company plc
#
# [1 rows x 4 columns]
#                name  ...                     comp_name
# 7  mr. timothy dove  ...  pioneer natural resources co
#
# [1 rows x 4 columns]
#                             name  ...          comp_name
# 3     dr. myles scoggins , ph.d.  ...  qep resources inc
# 15                mr. lyle flury  ...  qep resources inc
# 16  mr. robert (rob) mckee , iii  ...  qep resources inc
# 20              mr. keith rattie  ...  qep resources inc
# 24              mr. james harmon  ...  qep resources inc
# 25               ms. teresa beck  ...  qep resources inc
# 26                       r. cash  ...  qep resources inc
#
# [7 rows x 4 columns]
#                name  ...                 comp_name
# 3  ms. betty devita  ...  molson coors beverage co
#
# [1 rows x 4 columns]
#                     name  ...        comp_name
# 26    mr. roger linquist  ...  t-mobile us inc
# 28  mr. arthur patterson  ...  t-mobile us inc
#
# [2 rows x 4 columns]
#                 name         last_position executive_end           comp_name
# 8  mr. john mckinney  independent director          2017  united rentals inc
#                        name  ... comp_name
# 11  mr. byron pollitt , jr.  ...  visa inc
#
# [1 rows x 4 columns]
#                       name         last_position executive_end  comp_name
# 21  dr. john hamre , ph.d.  independent director          2013  xylem inc
# This many companies had directors with missing start dates: 38

# %% [markdown]
# These 38 cases could be checked manually and then the start date could be added manually.

# %% [markdown]
# ### Get all directors included in my dataset

# %%
# create dataframe that only contains director names, company names, company tickers, years, and ISINs
for i, df in enumerate(all_combined_dfs):
    try:
        df = df[['name', 'isin', 'comp_name', 'ticker', '2011', '2012', '2013', '2014', '2014']]

    except:
        print(i, df['ticker'][0])

# %%
# concat all data frames in all_combined_dfs to prepare for writing to csv file
all_final_directors_dfs = pd.concat(all_combined_dfs, ignore_index=True)
all_final_directors_dfs

# %%
# check how many unique directors are included
all_final_directors_dfs['name'].nunique()
# Out:
# 9465

# %%
# write data to csv files
all_final_directors_dfs.to_csv('/content/drive/My Drive/director-csr/all_directors.csv')

# %% [markdown]
# ## CSR committee data

# %%
# concat all data frames in all_committees_dfs to prepare for writing to csv file
all_final_committees_dfs = pd.concat(all_committees_dfs, ignore_index=True)
all_final_committees_dfs

# %%
# write data to csv files
all_final_committees_dfs.to_csv('/content/drive/My Drive/director-csr/all_committees.csv')
